# %% [markdown]
# # Mean Squared Error (Cost Function) and Gradient Descent

# %% [markdown]
# The Mean squared error is the delta between your actual delta püoint and the predicted data point, squared to avoid negative calculations and added together in the end, divided by the count n of all your points.

# %% [markdown]
# The Gradient Descent is an algorithm that helps find the best fit line for a given training data set. To find the global minimal, the derivatives of the respective functions are used to readjust direction.

# %%
import numpy as np

# %%
x = np.array([1,2,3,4,5])
y= np.array([5, 7, 9, 11, 13])

# %%
def gradient_descent(x, y):
    m_curr = b_curr = 0
    iterations = 10000
    n= len(x)
    learning_rate = 0.01

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        msq_cost = (1/n)*sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print("m {}, b {}, cost {}, iteration {}".format(m_curr, b_curr, msq_cost, i))



gradient_descent(x,y)
# Out:
# m 0.62, b 0.18, cost 89.0, iteration 0
# m 1.0928, b 0.3192, cost 52.25039999999999, iteration 1
# m 1.453232, b 0.42724799999999996, cost 30.831949440000002, iteration 2
# m 1.7278860800000002, b 0.5115091199999999, cost 18.347751350784, iteration 3
# m 1.9370605952000002, b 0.5776057727999999, cost 11.070010749324897, iteration 4
# m 2.096250917888, b 0.6298300216319999, cost 6.826353152519786, iteration 5
# m 2.2172859146547204, b 0.6714583661260799, cost 4.350826141683065, iteration 6
# m 2.309195511463117, b 0.7049920439242751, cost 2.9056952040975976, iteration 7
# m 2.3788729763057748, b 0.7323404723580026, cost 2.0610450731046615, iteration 8
# m 2.431580493177024, b 0.7549612843324961, cost 1.5663423003130599, iteration 9
# m 2.471335107618129, b 0.7739672290552247, cost 1.2755882811903883, iteration 10
# m 2.501203350198827, b 0.7902077780170325, cost 1.1037021437989751, iteration 11
# m 2.523526146474063, b 0.8043314214447622, cost 1.0011028556851886, iteration 12
# ...

# %% [markdown]
# # Exercise

# %%
import pandas as pd
import math
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# %%
df = pd.read_csv('exercise.csv')
df.head()
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83

# %%
x= np.array(df.math)
y= np.array(df.cs)

# %%
def gradient_descent(x, y):
    m_curr = b_curr = 0
    iterations = 1000000
    n= len(x)
    learning_rate = 0.0002

    cost_previous = 0

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        msq_cost = (1/n)*sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        if math.isclose(msq_cost, cost_previous, rel_tol=1e-20):
            break
        cost_previous = msq_cost
        print("m {}, b {}, cost {}, iteration {}".format(m_curr, b_curr, msq_cost, i))

gradient_descent(x,y)
# Out:
# m 1.9783600000000003, b 0.027960000000000002, cost 5199.1, iteration 0
# m 0.20975041279999962, b 0.0030470367999999894, cost 4161.482445460163, iteration 1
# m 1.7908456142986242, b 0.025401286955264, cost 3332.2237319269248, iteration 2
# m 0.37738163667530467, b 0.005499731626422651, cost 2669.4843523161976, iteration 3
# m 1.6409848166378898, b 0.023373894401807944, cost 2139.826383775145, iteration 4
# m 0.5113514173939655, b 0.0074774305434828076, cost 1716.5264071567592, iteration 5
# m 1.5212165764726306, b 0.021771129698498662, cost 1378.2272007804495, iteration 6
# m 0.6184191426785134, b 0.009075514323270572, cost 1107.8601808918404, iteration 7
# m 1.4254981563597626, b 0.020507724625171385, cost 891.7842215178443, iteration 8
# m 0.7039868810749315, b 0.010370210797388455, cost 719.0974036421305, iteration 9
# m 1.3490002310389348, b 0.01951553325074733, cost 581.0869686205, iteration 10
# m 0.7723719384951477, b 0.01142244086408669, cost 470.7897237271261, iteration 11
# ...

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['math']].values, df.cs)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([1.01773624])

# %%
reg.intercept_
# Out:
# 1.9152193111568891
